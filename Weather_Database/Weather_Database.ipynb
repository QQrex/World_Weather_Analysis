# %% [markdown]
# # Retrieve Weather Data

# %%
# Import the dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longtitdue combinations.

lats = np.random.uniform(low= -90.000, high= 90.000, size= 2000)
lngs = np.random.uniform(low= -180.000, high= 180.000, size= 2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we add it to the citites list.
    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm amount of cities

len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Test url + key

test_url = url + "&q=" + "Boston"

requests.get(test_url).json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 39.58,
#   'feels_like': 39.58,
#   'temp_min': 36.37,
#   'temp_max': 42.6,
#   'pressure': 1029,
#   'humidity': 90},
#  'visibility': 10000,
#  'wind': {'speed': 0, 'deg': 0},
#  'clouds': {'all': 100},
#  'dt': 1643841540,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1643803010,
#   'sunset': 1643839140},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# test API parse JSON for boston

test_city_weather = requests.get(test_url).json()
test_city_lat = test_city_weather['coord']['lat']
test_city_lon = test_city_weather['coord']['lon']
test_city_des = test_city_weather['weather'][0]['description']

test_city_des
# Out:
# 'overcast clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create end point URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # Add 1 to the record count.
    
    record_count +=1
    
    # Run an API request for each of the cities.
    
    try:
        # Parase the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather['weather'][0]['description']
            
        # convert the data to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into city_data_ list.
            
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date,
                            "Description": city_description})
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | berlevag
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | bilibino
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | lorengau
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | sortland
# Processing Record 16 of Set 1 | qasigiannguit
# Processing Record 17 of Set 1 | roma
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | chumikan
# Processing Record 21 of Set 1 | lokoja
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | cherskiy
# ...

# %%
len(city_data)
# Out:
# 702

# %%
# Transform city_data to DataFrame
city_data_df = pd.DataFrame(city_data)

# Reorder colums
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity',
                    'Cloudiness', 'Wind Speed', 'Description', 'Date']
city_dat_df = city_data_df[new_column_order]

city_data_df.head(1)
# Out:
#            City    Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Punta Arenas -53.15 -70.9167     48.31        71          75        8.05
#
#   Country                 Date    Description
# 0      CL  2022-02-02 22:50:20  broken clouds

# %%
city_data_df.isnull().sum()
# Out:
# City           0
# Lat            0
# Lng            0
# Max Temp       0
# Humidity       0
# Cloudiness     0
# Wind Speed     0
# Country        0
# Date           0
# Description    0
# dtype: int64

# %%
# Save DataFrame as csv

output_data_file = "Weather_Database/WeatherPY_Database.csv"

city_data_df.to_csv(output_data_file, index_label = 'City_ID')
